# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
print(("*")*120)
print(" \t\t\t\t**************DATASET:- Computer Science / Programing Books***************\n\nHigh rated book information in the field of computer science and programing")
print(("*")*120)
# Out:
# ************************************************************************************************************************
#  				**************DATASET:- Computer Science / Programing Books***************
#
# High rated book information in the field of computer science and programing
# ************************************************************************************************************************

# %%
df=pd.read_csv("prog_book.csv")
df
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
print(("*")*120)
print(" \t\t\t\t**************UNDERSTANDING OF DATA GIVEN***************\n\n(a) Rating ------- > The user rating for the book. the rating score ranges between 0 and 5.\n\n(b) Reviews ------- > The number of reviews found on this book.\n\n(c) Book_title ------- > The name of the book.\n\n(d) Description ------- > A short description of the book.\n\n(e) Number_Of_Pages ------- > Number of pages in the book.\n\n(f) Type ------- >The type of the book meaning is it a hardcover book or an ebook or a kindle book etc.\n\n(g) Price ------- > The average price of the book in USD where the average is calculated according the 5 web sources.")
print(("*")*120)
# Out:
# ************************************************************************************************************************
#  				**************UNDERSTANDING OF DATA GIVEN***************
#
# (a) Rating ------- > The user rating for the book. the rating score ranges between 0 and 5.
#
# (b) Reviews ------- > The number of reviews found on this book.
#
# (c) Book_title ------- > The name of the book.
#
# (d) Description ------- > A short description of the book.
#
# (e) Number_Of_Pages ------- > Number of pages in the book.
#
# (f) Type ------- >The type of the book meaning is it a hardcover book or an ebook or a kindle book etc.
#
# (g) Price ------- > The average price of the book in USD where the average is calculated according the 5 web sources.
# ************************************************************************************************************************

# %% [markdown]
# # BASIC INFORMATION OF THE DATASET

# %%
print(("*")*120)
print(" \t\t\t\t**************ANALYSIS***************\n\t\t\t\tMY DATASET HAS 7 COLUMNS AND 48895 ROWS.\n\t\t\t\tIT HAS 10 NUMERICAL COLUMNS AND 6 CATEGORICAL COLUMNS.\n\t\t\t\t4 COLUMNS HAS NULL VALUES.")
print(("*")*120)
df.info()
# Out:
# ************************************************************************************************************************
#  				**************ANALYSIS***************
# 				MY DATASET HAS 7 COLUMNS AND 48895 ROWS.
# 				IT HAS 10 NUMERICAL COLUMNS AND 6 CATEGORICAL COLUMNS.
# 				4 COLUMNS HAS NULL VALUES.
# ************************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rating           271 non-null    float64
#  1   Reviews          271 non-null    object
#  2   Book_title       271 non-null    object
#  3   Description      271 non-null    object
#  4   Number_Of_Pages  271 non-null    int64
#  5   Type             271 non-null    object
#  6   Price            271 non-null    float64
# ...

# %% [markdown]
# # FEATURES OF DATASET

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n~ PRICE:-Price of airbnb ranges between 0$ to 10000$, mean cost of an airbnb is 152$,but median cost is 106$ this implies there are large number of outliers present in price column.\n~ ALL FEATURES OF DATASET WILL BE ANALYSED IN DETAIL AS WE GO AHEAD IN PROJECT.")
print(("*")*120)
df.describe()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
# ~ PRICE:-Price of airbnb ranges between 0$ to 10000$, mean cost of an airbnb is 152$,but median cost is 106$ this implies there are large number of outliers present in price column.
# ~ ALL FEATURES OF DATASET WILL BE ANALYSED IN DETAIL AS WE GO AHEAD IN PROJECT.
# ************************************************************************************************************************
#            Rating  Number_Of_Pages       Price
# count  271.000000       271.000000  271.000000
# mean     4.067417       475.077491   54.541860
# std      0.290749       306.147492   35.711485
# min      3.000000        50.000000    9.323529
# 25%      3.915000       289.000000   30.751471
# 50%      4.100000       384.000000   46.317647
# 75%      4.250000       572.500000   67.854412
# max      5.000000      3168.000000  235.650000

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\t\t\t\t~ WE HAVE 47906 UNIQUE RECORDS IN NAME.\n\t\t\t\t~ WE HAVE 11452 UBNIQUE ROWS IN HOST_NAME\n\t\t\t\t~ Neighbourhood_group has 5 unique columns with highest frequency of Manhattan\n\t\t\t\t~ neighbourhood has 221 unique columns\n\t\t\t~~ ALL THIS FEATIRES WE WILL ANALYSED IN DETAIL AS WE GO AHEAD IN THIS PROJECT")
print(("*")*120)
df.describe(include="O")
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
# 				~ WE HAVE 47906 UNIQUE RECORDS IN NAME.
# 				~ WE HAVE 11452 UBNIQUE ROWS IN HOST_NAME
# 				~ Neighbourhood_group has 5 unique columns with highest frequency of Manhattan
# 				~ neighbourhood has 221 unique columns
# 			~~ ALL THIS FEATIRES WE WILL ANALYSED IN DETAIL AS WE GO AHEAD IN THIS PROJECT
# ************************************************************************************************************************
#        Reviews             Book_title  \
# count      271                    271
# unique     133                    271
# top          0  The Elements of Style
# freq        22                      1
#
#                                               Description       Type
# count                                                 271        271
# ...

# %% [markdown]
# # CLEANING DATA

# %% [markdown]
# # Finding null/missing values in the data if any.

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\t\t\t~We can clearly see True in output of some columns which contains null values")
print(("*")*120)
df.isnull().any()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
# 			~We can clearly see True in output of some columns which contains null values
# ************************************************************************************************************************
# Rating             False
# Reviews            False
# Book_title         False
# Description        False
# Number_Of_Pages    False
# Type               False
# Price              False
# dtype: bool

# %% [markdown]
# # finding % of null values

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n~ reviews_per_month column has approximately 20% null values which i will fill with mean value of this columns.\n~ last_review column also has 20% null values,for my analysis i donot require this column so i will be droping whole column\n~ name and host_name has less than 0.05% null values,i will be droping this null rows.")
print(("*")*120)
df.isnull().sum()/len(df)*100
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
# ~ reviews_per_month column has approximately 20% null values which i will fill with mean value of this columns.
# ~ last_review column also has 20% null values,for my analysis i donot require this column so i will be droping whole column
# ~ name and host_name has less than 0.05% null values,i will be droping this null rows.
# ************************************************************************************************************************
# Rating             0.0
# Reviews            0.0
# Book_title         0.0
# Description        0.0
# Number_Of_Pages    0.0
# Type               0.0
# Price              0.0
# dtype: float64

# %%
df['Reviews']=df['Reviews'].map(lambda x: x.replace(',',''))
df['Reviews']=pd.to_numeric(df['Reviews'])

# %% [markdown]
# # Some books have no reviewers

# %%
df_corr=df.copy()
df_Reviews=df_corr["Reviews"]

# %%
point_0=(df_Reviews==0)

# %%
df[point_0]
# Out:
#      Rating  Reviews                                         Book_title  \
# 2      3.33        0       Responsive Web Design Overview For Beginners
# 9      4.62        0  ZX Spectrum Games Code Club: Twenty fun games ...
# 24     3.20        0                      Game Programming Golden Rules
# 41     4.33        0  Beginners Guide On PHP Programming: Quick And ...
# 44     4.00        0  Python Programming Books Set: Python Programmi...
# 54     5.00        0                            Your First App: Node.js
# 64     3.91        0  Python Programming For Beginners: Quick And Ea...
# 148    4.00        0                    Building an FPS Game with Unity
# 177    3.00        0  Advanced Game Programming: A Gamedev.Net Colle...
# 178    3.83        0                                 Basic Proof Theory
# 182    3.00        0  Cross-Platform Game Programming (Game Developm...
# 187    3.00        0  Lambda-Calculus, Combinators and Functional Pr...
# ...

# %%
print(("*")*120)
print("\tSome books have no reviewers but have rating .We have inconsistent data.I will fill it with the average value instead of inconsistent data")
print(("*")*120)
# Out:
# ************************************************************************************************************************
# 	Some books have no reviewers but have rating .We have inconsistent data.I will fill it with the average value instead of inconsistent data
# ************************************************************************************************************************

# %%
from math import *
df_Reviews[point_0]=ceil(df.Reviews.mean())

# %%
df["Reviews"]=df_Reviews
df[point_0]
# Out:
#      Rating  Reviews                                         Book_title  \
# 2      3.33      186       Responsive Web Design Overview For Beginners
# 9      4.62      186  ZX Spectrum Games Code Club: Twenty fun games ...
# 24     3.20      186                      Game Programming Golden Rules
# 41     4.33      186  Beginners Guide On PHP Programming: Quick And ...
# 44     4.00      186  Python Programming Books Set: Python Programmi...
# 54     5.00      186                            Your First App: Node.js
# 64     3.91      186  Python Programming For Beginners: Quick And Ea...
# 148    4.00      186                    Building an FPS Game with Unity
# 177    3.00      186  Advanced Game Programming: A Gamedev.Net Colle...
# 178    3.83      186                                 Basic Proof Theory
# 182    3.00      186  Cross-Platform Game Programming (Game Developm...
# 187    3.00      186  Lambda-Calculus, Combinators and Functional Pr...
# ...

# %%
df['Reviews']=df['Reviews'].convert_dtypes()

# %%
df['Reviews']=df['Reviews'].astype(str)

# %%
df['Reviews'] = df['Reviews'].astype(int)

# %%
df['Reviews'] = df['Reviews'].replace(',', '')
df.head()
# Out:
#    Rating  Reviews                                         Book_title  \
# 0    4.17     3829                              The Elements of Style
# 1    4.01     1406      The Information: A History, a Theory, a Flood
# 2    3.33      186       Responsive Web Design Overview For Beginners
# 3    3.97     1658  Ghost in the Wires: My Adventures as the World...
# 4    4.06     1325                                   How Google Works
#
#                                          Description  Number_Of_Pages  \
# 0  This style manual offers practical advice on i...              105
# 1  James Gleick, the author of the best sellers C...              527
# 2  In Responsive Web Design Overview For Beginner...               50
# 3  If they were a hall of fame or shame for compu...              393
# 4  Both Eric Schmidt and Jonathan Rosenberg came ...              305
#
#              Type      Price
# 0       Hardcover   9.323529
# 1       Hardcover  11.000000
# 2  Kindle Edition  11.267647
# ...

# %%
print(("*")*120)
print("\t\t\t\tDroping null rows of columns name and host_name")
print(("*")*120)
df.dropna(inplace=True)
df
# Out:
# ************************************************************************************************************************
# 				Droping null rows of columns name and host_name
# ************************************************************************************************************************
#      Rating  Reviews                                         Book_title  \
# 0      4.17     3829                              The Elements of Style
# 1      4.01     1406      The Information: A History, a Theory, a Flood
# 2      3.33      186       Responsive Web Design Overview For Beginners
# 3      3.97     1658  Ghost in the Wires: My Adventures as the World...
# 4      4.06     1325                                   How Google Works
# ..      ...      ...                                                ...
# 266    3.76      186  3D Game Engine Architecture: Engineering Real-...
# 267    3.94       22                An Introduction to Database Systems
# ...

# %%
print(("*")*120)
print("\t\t\t\tNOW RESETING INDEX TO GET DEFAULT INDEXES.")
print(("*")*120)
df.reset_index(drop=True,inplace=True)
df
# Out:
# ************************************************************************************************************************
# 				NOW RESETING INDEX TO GET DEFAULT INDEXES.
# ************************************************************************************************************************
#      Rating  Reviews                                         Book_title  \
# 0      4.17     3829                              The Elements of Style
# 1      4.01     1406      The Information: A History, a Theory, a Flood
# 2      3.33      186       Responsive Web Design Overview For Beginners
# 3      3.97     1658  Ghost in the Wires: My Adventures as the World...
# 4      4.06     1325                                   How Google Works
# ..      ...      ...                                                ...
# 266    3.76      186  3D Game Engine Architecture: Engineering Real-...
# 267    3.94       22                An Introduction to Database Systems
# ...

# %%
print(("*")*120)
print("\t\t\t\tI HAVE CLEANED ALL NULL VALUES AND UNWANTED COLUMNS FROM MY DATA SET.")
print(("*")*120)
df.isnull().sum()/len(df)*100
# Out:
# ************************************************************************************************************************
# 				I HAVE CLEANED ALL NULL VALUES AND UNWANTED COLUMNS FROM MY DATA SET.
# ************************************************************************************************************************
# Rating             0.0
# Reviews            0.0
# Book_title         0.0
# Description        0.0
# Number_Of_Pages    0.0
# Type               0.0
# Price              0.0
# dtype: float64

# %% [markdown]
# # Q1) Counts of different types of Books

# %%
df["Type"].value_counts()
# Out:
# Type
# Paperback                156
# Hardcover                 95
# Kindle Edition            10
# ebook                      7
# Unknown Binding            2
# Boxed Set - Hardcover      1
# Name: count, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\t\t\t(1)Highest types of book is Paperback \n\t\t\t(2)Lowest types of books is Boxed Set - Hardcover\n\t\t\t")
print(("*")*120)
plt.figure(figsize=(16,4))
ax = sns.countplot(x="Type", data=df);
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
# 			(1)Highest types of book is Paperback
# 			(2)Lowest types of books is Boxed Set - Hardcover
#
# ************************************************************************************************************************

# %% [markdown]
# # Q2) Distribution of Book Prices based on Rating

# %%
p1=df.groupby("Price")["Rating"].count().sort_values(ascending=False)
p1
# Out:
# Price
# 51.473529     5
# 60.682353     4
# 91.047059     3
# 69.379412     2
# 59.082353     2
#              ..
# 37.323529     1
# 37.432353     1
# 37.661765     1
# 38.235294     1
# 235.650000    1
# Name: Rating, Length: 241, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\t\tMost books are betwwen price range 30 to 100 with average rating")
print(("*")*120)
sns.scatterplot(data=df,x='Price',y='Rating')
plt.grid()
plt.show()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
# 		Most books are betwwen price range 30 to 100 with average rating
# ************************************************************************************************************************

# %% [markdown]
# # Q3) Reviews according to different types of books.

# %%
p2=df.groupby("Type")["Reviews"].mean().sort_values(ascending=False)
p2
# Out:
# Type
# Hardcover                334.757895
# Kindle Edition           175.100000
# Paperback                128.179487
# Unknown Binding          123.500000
# ebook                     78.000000
# Boxed Set - Hardcover     36.000000
# Name: Reviews, dtype: float64

# %%
df.groupby("Type")["Reviews"].mean().sort_values(ascending=False).plot(kind="bar")
plt.show()

# %% [markdown]
# # Q4) FIND 5 BOOK TITLE WITH LOWEST RATINGS

# %%
df.groupby("Book_title")["Rating"].value_counts().sort_values(ascending=False).tail(5)
# Out:
# Book_title                                                     Rating
# Expert C Programming: Deep C Secrets                           4.32      1
# Extreme Programming Explained: Embrace Change (The XP Series)  4.08      1
# Fearless Change: Patterns for Introducing New Ideas            3.97      1
# Feynman Lectures On Computation                                4.23      1
# xUnit Test Patterns: Refactoring Test Code                     3.94      1
# Name: count, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n~~(1) We can see that there are multiple neighbourhoods with only 1 AIRBNB, tourists are least intersted in this places.") 
print(("*")*120)
df.groupby("Book_title")["Rating"].value_counts().sort_values(ascending=False).tail(5).plot(kind="barh")
plt.xlabel("Rating")
plt.show()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# ~~(1) We can see that there are multiple neighbourhoods with only 1 AIRBNB, tourists are least intersted in this places.
# ************************************************************************************************************************

# %%
df.groupby("Book_title")["Reviews"].value_counts().sort_values(ascending=False).tail(5)
# Out:
# Book_title                                                     Reviews
# Expert C Programming: Deep C Secrets                           39         1
# Extreme Programming Explained: Embrace Change (The XP Series)  163        1
# Fearless Change: Patterns for Introducing New Ideas            18         1
# Feynman Lectures On Computation                                18         1
# xUnit Test Patterns: Refactoring Test Code                     45         1
# Name: count, dtype: int64

# %%
df.groupby("Book_title")["Reviews"].value_counts().sort_values(ascending=False).tail(5).plot(kind="pie")
plt.xlabel("Reviews")
plt.show()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# ~~(1) We can see that there are multiple neighbourhoods with only 1 AIRBNB, tourists are least intersted in this places.
# ************************************************************************************************************************

# %%
# Filter for only hardcover books
hardcover_df = df[df['Type'] == 'Hardcover']

# Sort by price descending and take the top 5 rows
top5 = hardcover_df.sort_values('Price', ascending=False).head(5)

# Create the plot
plt.figure(figsize=(13,9))
ax = plt.subplot(111)
ax.barh(top5['Book_title'], top5['Price'])
ax.set_ylabel('Book Title')
ax.set_xlabel('Price ($)')
plt.title('Top 5 Most Expensive Hardcover Books')


# Add data labels
for i, v in enumerate(top5['Price']):
    ax.text(v + 3, i, str(v), color='blue', fontweight='bold')


plt.show()

# %%
# Scatter plot of rating vs pages 
plt.scatter(df['Number_Of_Pages'], df['Rating'])
plt.xlabel('Number of Pages')
plt.ylabel('Rating')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Bar chart of average rating by type
type_group = df.groupby('Type')['Rating'].mean()
type_group.plot.bar()
  
plt.xlabel('Book Type')
plt.ylabel('Average Rating')
plt.tight_layout()
plt.show()

# %%
# Histogram of book prices
plt.hist(df['Price'], bins=20)

plt.xlabel('Price')
plt.ylabel('Frequency')
plt.tight_layout()  
plt.show()

# %%
avg_rating = df.groupby('Type')['Rating'].mean()
plt.figure(figsize=(16,4))
plt.bar(avg_rating.index, avg_rating)
plt.xlabel('Book Type')
plt.ylabel('Average Rating')
# Out:
# Text(0, 0.5, 'Average Rating')

# %%
formats = df['Type'].value_counts()
plt.pie(formats, labels=formats.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x21808620d90>,
# ...
#  [Text(-0.258959246721408, 1.0690837705893217, 'Paperback'),
#   Text(0.006375834103521128, -1.0999815219991127, 'Hardcover'),
#   Text(1.0341456116224346, -0.3748904559495493, 'Kindle Edition'),
#   Text(1.087532233188004, -0.1651473335452717, 'ebook'),
#   Text(1.0988175935413387, -0.05098917653798077, 'Unknown Binding'),
#   Text(1.0999260867891085, -0.0127516116941638, 'Boxed Set - Hardcover')])

# %%
plt.hist(df['Number_Of_Pages'])
# Out:
# (array([123.,  99.,  33.,  14.,   1.,   0.,   0.,   0.,   0.,   1.]),
#  array([  50. ,  361.8,  673.6,  985.4, 1297.2, 1609. , 1920.8, 2232.6,
#         2544.4, 2856.2, 3168. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x=df['Reviews'], y=df['Rating'])
